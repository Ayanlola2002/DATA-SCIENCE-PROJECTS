# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayanlola2002/DATA-SCIENCE-PROJECTS/blob/master/SalesData_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %%
train=pd.read_csv('/content/salesData.csv',dtype={'Thickness':str,'ItemCost':str,'Sales Price':str,'Batch Quantity':str,'Vat Value':str,'Sales Amount':str})

# %%
train.loc[[6964,6965,6966]]
# Out:
#          # Coil Pattern   Group Name1  ... Batch Quantity  Vat Value  Sales Amount
# 6964  6965     Embossed  FG ALUMINIUM  ...       1,620.00  53,055.00  1,061,100.00
# 6965  6966     Embossed  FG ALUMINIUM  ...       2,065.00  67,628.75  1,352,575.00
# 6966  6967     Embossed  FG ALUMINIUM  ...       1,950.00  63,862.50  1,277,250.00
#
# [3 rows x 22 columns]

# %%
train['Doc. Date']=pd.to_datetime(train['Doc. Date'],dayfirst=True)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77895 entries, 0 to 77894
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   #                 77895 non-null  int64
#  1   Coil Pattern      77895 non-null  object
#  2   Group Name1       77895 non-null  object
#  3   Product           77895 non-null  object
#  4   Document Number   77895 non-null  int64
#  5   Doc. Date         77895 non-null  datetime64[ns]
#  6   Week              77895 non-null  object
#  7   Month             77895 non-null  int64
#  8   Group Name2       77895 non-null  object
#  9   Customer Code     77895 non-null  object
#  10  Customer Name     77895 non-null  object
#  11  Item Code         77895 non-null  object
#  12  Item Description  77895 non-null  object
#  13  Thickness         77895 non-null  object
#  14  Width             77895 non-null  int64
#  15  Colour            77895 non-null  object
#  16  Batch Number      77895 non-null  object
#  17  ItemCost          77895 non-null  object
#  18  Sales Price       77895 non-null  object
#  19  Batch Quantity    77895 non-null  object
#  20  Vat Value         77895 non-null  object
#  21  Sales Amount      77895 non-null  object
# dtypes: datetime64[ns](1), int64(4), object(17)
# memory usage: 13.1+ MB

# %%
#check for null values
train.isnull().sum()
# Out:
# #                   0
# Coil Pattern        0
# Group Name1         0
# Product             0
# Document Number     0
# Doc. Date           0
# Week                0
# Month               0
# Group Name2         0
# Customer Code       0
# Customer Name       0
# Item Code           0
# Item Description    0
# Thickness           0
# Width               0
# Colour              0
# Batch Number        0
# ItemCost            0
# Sales Price         0
# Batch Quantity      0
# Vat Value           0
# Sales Amount        0
# dtype: int64

# %%
train.tail()
# Out:
#            # Coil Pattern   Group Name1  ... Batch Quantity  Vat Value Sales Amount
# 77890  77891     Embossed  FG ALUMINIUM  ...             46     525.73    10,514.68
# 77891  77892     Embossed  FG ALUMINIUM  ...             48     548.59    10,971.84
# 77892  77893     Embossed  FG ALUMINIUM  ...             60     685.74    13,714.80
# 77893  77894     Embossed  FG ALUMINIUM  ...            160   1,828.64    36,572.80
# 77894  77895     Embossed  FG ALUMINIUM  ...            160   1,828.64    36,572.80
#
# [5 rows x 22 columns]

# %%
#some values has string needs to be removed
train['Thickness'].unique()
# Out:
# array(['0.7', '0.55', '0.45', '0.6', '0.4', '0.5', '0.8', '0.35', '0.3',
#        '1', '0.65', '1.2', '0.25', '0.9', '0.72', '0.26', '0.53', '0.42',
#        '0.52', '0.75', '0.57', '0.43', '0.63', '0.67', '0.62', '0.40B',
#        '0.40C', '0.2', '0.28', '0.37', '0.23', '0.32', '0.38', '0.27',
#        '0.31', '0.15', '0.18', '0.33', '0.47'], dtype=object)

# %%
#checking datatypes of columns for object datatype
train['Thickness'].apply(type).value_counts()
# Out:
# <class 'str'>    77895
# Name: Thickness, dtype: int64

# %%
#can be converted directly by astype
train['ItemCost'].unique()
# Out:
# array(['508.8909', '517.5291', '526.0892', ..., '16.3102', '504.1657',
#        '513.7143'], dtype=object)

# %%
#checking datatypes of columns for object datatype
train['ItemCost'].apply(type).value_counts()
# Out:
# <class 'str'>    77895
# Name: ItemCost, dtype: int64

# %%
#can be converted directly by astype
train['Sales Price'].unique()
# Out:
# array(['649', '639', '654', '647', '664', '659', '660.52', '454.22',
#        '621', '645.82', '631', '694', '653.66', '504', '657', '685',
#        '506.55', '450', '500', '462', '580', '480', '669', '465.08',
#        '465', '643', '628', '638', '600', '636', '440', '634', '437.13',
#        '648', '656', '663', '453', '449.98', '499.58', '658', '523.81',
#        '409.52', '505', '1,100.00', '718', '485', '517.25', '483.2',
#        '400', '469.61', '504.34', '487.73', '655', '650', '504.76', '665',
#        '504.77', '680', '670', '678', '552.4', '551.15', '532', '350',
#        '665.72', '675.24', '560', '705', '690', '698', '710', '535.5',
#        '584.29', '325', '748', '725', '556.74', '564.26', '573.25',
#        '676.19', '575.28', '558.45', '713', '484.17', '528.61', '572.98',
#        '696', '468.18', '554.78', '686', '0.0001', '701', '693', '575.97',
#        '695', '671', '586.68', '727.3', '518.67', '675', '671.43', '676',
#        '672', '533', '688', '537', '674.29', '720', '711', '703', '597',
#        '610', '529', '620', '723', '740', '792', '712.51', '516.5', '405',
#        '700', '420', '386', '543.2', '602.32', '506.32', '772', '715',
#        '745', '750', '780', '496.93', '611.31', '513.88', '775', '575',
#        '756', '556', '565', '754.8', '403.3', '660', '630', '625', '496',
#        '545', '598.5', '524', '427', '645', '640', '635', '530', '580.5',
#        '550', '422.06', '300', '652', '476.19', '668', '0', '622',
#        '609.52', '430', '608.38', '617.88', '642', '624', '623.99',
#        '527.51', '508.022', '600.936', '80', '730', '512.66', '660.505',
#        '800', '785', '755', '810', '795.88', '790', '590', '604', '627',
#        '370', '360', '435', '330', '140', '340', '314.29', '419.05',
#        '285.71', '320', '425', '285.72', '170', '381', '385', '366',
#        '310', '200', '390', '371', '315', '250', '415', '396', '345',
#        '419', '424', '362.5', '445', '401', '314.28', '380', '333.33',
#        '333', '481', '547', '480.4', '536', '520', '100', '339', '354',
#        '335', '150', '355', '365', '109.25', '90', '110', '120', '130',
#        '49.399', '59.279', '49.4005', '42.812', '20.583', '18.296',
#        '30.58', '35.677', '220', '44.83', '37.28', '198.9', '280', '105',
#        '70', '63.72', '53.1', '12', '49.66', '25.34', '2.79', '53.09',
#        '39.4', '69.33', '62.73', '50.88', '61.056', '62.67', '61.56',
#        '51', '4.31', '44.2', '61.06', '32.83', '28.03', '41.1', '34.55',
#        '42.8', '39.39', '47.93', '74.688', '42.02', '37.714', '34.456',
#        '28.111', '33.18', '45.482', '62.24', '60.32', '50.267', '62.4',
#        '73.74', '86.188', '53.52', '49.214', '37.366', '10', '45.452',
#        '82.468', '45.051', '83.468', '70.002', '70.02', '48.762',
#        '40.434', '72.468', '74.468', '84.468', '61.263', '76.244',
#        '53.643', '47.013', '43.434', '34.297', '61.577', '35.413', '6',
#        '49.2', '45.455', '80.393', '37.136', '74.169', '45.306', '56.138',
#        '67.251', '40.796', '35.892', '47.03', '49.697', '85.323',
#        '53.792', '47.273', '79.061', '41.752', '49.679', '51.605',
#        '32.451', '30.621', '50.905', '30.62', '78', '81', '85.5', '87',
#        '92', '99', '94', '85', '270', '265', '260', '275', '240', '75',
#        '76.1905', '76', '79.8', '673', '228.58'], dtype=object)

# %%
#checking datatypes of columns for object datatype
train['Sales Price'].apply(type).value_counts()
# Out:
# <class 'str'>    77895
# Name: Sales Price, dtype: int64

# %%
#can be converted directly by astype
train['Batch Quantity'].unique()
# Out:
# array(['3,600.00', '3,250.00', '2,170.00', ..., '4,297.00', '5,110.00',
#        '5,115.00'], dtype=object)

# %%
#can be converted directly by astype
train['Vat Value'].unique()
# Out:
# array(['116,820.00', '105,462.50', '70,416.50', ..., '502.88', '422.87',
#        '1,828.64'], dtype=object)

# %%
#can be converted directly by astype
train['Sales Amount'].unique()
# Out:
# array(['2,336,400.00', '2,109,250.00', '1,408,330.00', ..., '10,057.52',
#        '8,457.46', '36,572.80'], dtype=object)

# %%
def clean_currency(x):
    
    """ If the value is a string, then remove currency symbol and delimiters
    otherwise, the value is numeric and can be converted
    """
    if isinstance(x, str):
        return(x.replace(',',''))
    return(x)

# %%
import re
def get_date_part(df):
    df['Year']=df['Doc. Date'].dt.year.astype('int')
    df['Month_Of_year']=df['Doc. Date'].dt.month.astype('int')
    df['Day_Of_Month']=df['Doc. Date'].dt.day.astype('int')
    df['Week_of_Month']=df['Doc. Date'].dt.weekday.astype('int')
    df['Thickness']=df['Thickness'].str.replace('[^\d.]','').astype('float')
    df['Width']=df['Width'].astype('float')
    df['ItemCost']=df['ItemCost'].apply(clean_currency).astype('float')
    df['Sales Price']=df['Sales Price'].apply(clean_currency).astype('float')
    df['Batch Quantity']=df['Batch Quantity'].apply(clean_currency).astype('float')
    df['Vat Value']=df['Vat Value'].apply(clean_currency).astype('float')
    df['Sales Amount']=df['Sales Amount'].apply(clean_currency).astype('float')
    return df
 #df.code.str.replace('[^\d.]', '').astype(float)

# %%
get_date_part(train)
# Out:
#            # Coil Pattern  ... Day_Of_Month Week_of_Month
# 0          1     Embossed  ...            3             1
# 1          2     Embossed  ...            3             1
# 2          3     Embossed  ...            3             1
# 3          4     Embossed  ...            3             1
# 4          5     Embossed  ...            3             1
# ...      ...          ...  ...          ...           ...
# 77890  77891     Embossed  ...            5             4
# 77891  77892     Embossed  ...            5             4
# 77892  77893     Embossed  ...            5             4
# 77893  77894     Embossed  ...            5             4
# 77894  77895     Embossed  ...            5             4
#
# [77895 rows x 26 columns]

# %%
train.loc[[6964,6965,6966]]
# Out:
#          # Coil Pattern  ... Day_Of_Month Week_of_Month
# 6964  6965     Embossed  ...           28             3
# 6965  6966     Embossed  ...           28             3
# 6966  6967     Embossed  ...           28             3
#
# [3 rows x 26 columns]

# %%
train
# Out:
#            # Coil Pattern  ... Day_Of_Month Week_of_Month
# 0          1     Embossed  ...            3             1
# 1          2     Embossed  ...            3             1
# 2          3     Embossed  ...            3             1
# 3          4     Embossed  ...            3             1
# 4          5     Embossed  ...            3             1
# ...      ...          ...  ...          ...           ...
# 77890  77891     Embossed  ...            5             4
# 77891  77892     Embossed  ...            5             4
# 77892  77893     Embossed  ...            5             4
# 77893  77894     Embossed  ...            5             4
# 77894  77895     Embossed  ...            5             4
#
# [77895 rows x 26 columns]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77895 entries, 0 to 77894
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   #                 77895 non-null  int64
#  1   Coil Pattern      77895 non-null  object
#  2   Group Name1       77895 non-null  object
#  3   Product           77895 non-null  object
#  4   Document Number   77895 non-null  int64
#  5   Doc. Date         77895 non-null  datetime64[ns]
#  6   Week              77895 non-null  object
#  7   Month             77895 non-null  int64
#  8   Group Name2       77895 non-null  object
#  9   Customer Code     77895 non-null  object
#  10  Customer Name     77895 non-null  object
#  11  Item Code         77895 non-null  object
#  12  Item Description  77895 non-null  object
#  13  Thickness         77895 non-null  float64
#  14  Width             77895 non-null  float64
#  15  Colour            77895 non-null  object
#  16  Batch Number      77895 non-null  object
#  17  ItemCost          77895 non-null  float64
#  18  Sales Price       77895 non-null  float64
#  19  Batch Quantity    77895 non-null  float64
#  20  Vat Value         77895 non-null  float64
#  21  Sales Amount      77895 non-null  float64
#  22  Year              77895 non-null  int64
#  23  Month_Of_year     77895 non-null  int64
#  24  Day_Of_Month      77895 non-null  int64
#  25  Week_of_Month     77895 non-null  int64
# dtypes: datetime64[ns](1), float64(7), int64(7), object(11)
# memory usage: 15.5+ MB

# %%
#subset the data tocapture relevant data
train=train[['Customer Code','Coil Pattern','Group Name2','Thickness','Width','Colour','ItemCost','Sales Price','Vat Value','Sales Amount','Year','Month_Of_year','Day_Of_Month','Week_of_Month','Batch Quantity']]

# %%
train.columns
# Out:
# Index(['Customer Code', 'Coil Pattern', 'Group Name2', 'Thickness', 'Width',
#        'Colour', 'ItemCost', 'Sales Price', 'Vat Value', 'Sales Amount',
#        'Year', 'Month_Of_year', 'Day_Of_Month', 'Week_of_Month',
#        'Batch Quantity'],
#       dtype='object')

# %%
#change column names
#Change coluumns names
train.columns =['cust_code','coil_pattern','grp_name','thickness','width','colour','item_Cost','sales_price','vatval','sales_amt','year','month','day','week','order_qty']

# %%
train
# Out:
#       cust_code coil_pattern              grp_name  ...  day  week order_qty
# 0       CIT0005     Embossed  Local Group Tower Al  ...    3     1    3600.0
# 1       CIT0005     Embossed  Local Group Tower Al  ...    3     1    3250.0
# 2       CIT0005     Embossed  Local Group Tower Al  ...    3     1    2170.0
# 3       CIT0005     Embossed  Local Group Tower Al  ...    3     1    3410.0
# 4       CIT0005     Embossed  Local Group Tower Al  ...    3     1    2815.0
# ...         ...          ...                   ...  ...  ...   ...       ...
# 77890   CIA0009     Embossed  Local Group Tower Al  ...    5     4      46.0
# 77891   CIA0009     Embossed  Local Group Tower Al  ...    5     4      48.0
# 77892   CIA0009     Embossed  Local Group Tower Al  ...    5     4      60.0
# 77893   CIA0009     Embossed  Local Group Tower Al  ...    5     4     160.0
# 77894   CIA0009     Embossed  Local Group Tower Al  ...    5     4     160.0
#
# [77895 rows x 15 columns]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77895 entries, 0 to 77894
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cust_code     77895 non-null  object
#  1   coil_pattern  77895 non-null  object
#  2   grp_name      77895 non-null  object
#  3   thickness     77895 non-null  float64
#  4   width         77895 non-null  float64
#  5   colour        77895 non-null  object
#  6   item_Cost     77895 non-null  float64
#  7   sales_price   77895 non-null  float64
#  8   vatval        77895 non-null  float64
#  9   sales_amt     77895 non-null  float64
#  10  year          77895 non-null  int64
#  11  month         77895 non-null  int64
#  12  day           77895 non-null  int64
#  13  week          77895 non-null  int64
#  14  order_qty     77895 non-null  float64
# dtypes: float64(7), int64(4), object(4)
# memory usage: 8.9+ MB

# %%
train_copy=train.copy()

# %%
train_copy
# Out:
#       cust_code coil_pattern              grp_name  ...  day  week order_qty
# 0       CIT0005     Embossed  Local Group Tower Al  ...    3     1    3600.0
# 1       CIT0005     Embossed  Local Group Tower Al  ...    3     1    3250.0
# 2       CIT0005     Embossed  Local Group Tower Al  ...    3     1    2170.0
# 3       CIT0005     Embossed  Local Group Tower Al  ...    3     1    3410.0
# 4       CIT0005     Embossed  Local Group Tower Al  ...    3     1    2815.0
# ...         ...          ...                   ...  ...  ...   ...       ...
# 77890   CIA0009     Embossed  Local Group Tower Al  ...    5     4      46.0
# 77891   CIA0009     Embossed  Local Group Tower Al  ...    5     4      48.0
# 77892   CIA0009     Embossed  Local Group Tower Al  ...    5     4      60.0
# 77893   CIA0009     Embossed  Local Group Tower Al  ...    5     4     160.0
# 77894   CIA0009     Embossed  Local Group Tower Al  ...    5     4     160.0
#
# [77895 rows x 15 columns]

# %%
train_set=train.loc[train['year'].isin([2010,2011,2012,2013,2014])]

# %%
train_set
# Out:
#       cust_code coil_pattern              grp_name  ...  day  week order_qty
# 0       CIT0005     Embossed  Local Group Tower Al  ...    3     1    3600.0
# 1       CIT0005     Embossed  Local Group Tower Al  ...    3     1    3250.0
# 2       CIT0005     Embossed  Local Group Tower Al  ...    3     1    2170.0
# 3       CIT0005     Embossed  Local Group Tower Al  ...    3     1    3410.0
# 4       CIT0005     Embossed  Local Group Tower Al  ...    3     1    2815.0
# ...         ...          ...                   ...  ...  ...   ...       ...
# 77890   CIA0009     Embossed  Local Group Tower Al  ...    5     4      46.0
# 77891   CIA0009     Embossed  Local Group Tower Al  ...    5     4      48.0
# 77892   CIA0009     Embossed  Local Group Tower Al  ...    5     4      60.0
# 77893   CIA0009     Embossed  Local Group Tower Al  ...    5     4     160.0
# 77894   CIA0009     Embossed  Local Group Tower Al  ...    5     4     160.0
#
# [68954 rows x 15 columns]

# %%
test_set=train.loc[train['year']==2015]

# %%
#checking if test is upto 12th month
test_set.loc[test_set['month']==12]
# Out:
#       cust_code coil_pattern              grp_name  ...  day  week order_qty
# 38463   CIT0005     Embossed  Local Group Tower Al  ...    2     2    2736.0
# 38464   CIT0005     Embossed  Local Group Tower Al  ...    2     2    1665.0
# 38465   CIT0005     Embossed  Local Group Tower Al  ...    2     2     749.0
# 38466   CIT0005     Embossed  Local Group Tower Al  ...    2     2    1812.0
# 38467   CIT0005     Embossed  Local Group Tower Al  ...    2     2    2208.0
# ...         ...          ...                   ...  ...  ...   ...       ...
# 77269   CEO0007  Un-Embossed       Local Non Group  ...   17     3    4009.0
# 77270   CEO0007  Un-Embossed       Local Non Group  ...   17     3    3733.0
# 77271   CEO0007  Un-Embossed       Local Non Group  ...   17     3    3793.0
# 77272   CEO0007  Un-Embossed       Local Non Group  ...   17     3    4780.0
# 77273   CEO0007  Un-Embossed       Local Non Group  ...   17     3    2261.0
#
# [341 rows x 15 columns]

# %%
#storing as csv
train_name='train.csv'
test_name='test.csv'
train_set.to_csv(train_name, encoding='utf-8', index=False)
test_set.to_csv(test_name, encoding='utf-8', index=False)

# %%
#storing as csv
#file_name='sales.csv'
#train.to_csv(file_name, encoding='utf-8', index=False)

# %%
train_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 68954 entries, 0 to 77894
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cust_code     68954 non-null  object
#  1   coil_pattern  68954 non-null  object
#  2   grp_name      68954 non-null  object
#  3   thickness     68954 non-null  float64
#  4   width         68954 non-null  float64
#  5   colour        68954 non-null  object
#  6   item_Cost     68954 non-null  float64
#  7   sales_price   68954 non-null  float64
#  8   vatval        68954 non-null  float64
#  9   sales_amt     68954 non-null  float64
#  10  year          68954 non-null  int64
#  11  month         68954 non-null  int64
#  12  day           68954 non-null  int64
#  13  week          68954 non-null  int64
#  14  order_qty     68954 non-null  float64
# dtypes: float64(7), int64(4), object(4)
# memory usage: 8.4+ MB

# %%
test_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8941 entries, 34558 to 77393
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cust_code     8941 non-null   object
#  1   coil_pattern  8941 non-null   object
#  2   grp_name      8941 non-null   object
#  3   thickness     8941 non-null   float64
#  4   width         8941 non-null   float64
#  5   colour        8941 non-null   object
#  6   item_Cost     8941 non-null   float64
#  7   sales_price   8941 non-null   float64
#  8   vatval        8941 non-null   float64
#  9   sales_amt     8941 non-null   float64
#  10  year          8941 non-null   int64
#  11  month         8941 non-null   int64
#  12  day           8941 non-null   int64
#  13  week          8941 non-null   int64
#  14  order_qty     8941 non-null   float64
# dtypes: float64(7), int64(4), object(4)
# memory usage: 1.1+ MB

# %%
from keras.callbacks import ModelCheckpoint
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error 
from matplotlib import pyplot as plt
import seaborn as sb
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import warnings 
warnings.filterwarnings('ignore')
warnings.filterwarnings('ignore', category=DeprecationWarning)
from xgboost import XGBRegressor

# %%
def get_data():
    #get train data
    train_data_path ='/content/train.csv'
    train = pd.read_csv(train_data_path)
    
    #get test data
    test_data_path ='/content/test.csv'
    test = pd.read_csv(test_data_path)
    
    return train , test

def get_combined_data():
    #reading train data
    train , test = get_data()
    target = train.order_qty
    train.drop(['order_qty'],axis = 1 , inplace = True)
    combined = train.append(test)
    combined.reset_index(inplace=True)
    combined.drop(['index','cust_code'], inplace=True, axis=1)
    return combined, target

#Load train and test data into pandas DataFrames
train_data, test_data = get_data()

#Combine train and test data to process them together
combined, target =get_combined_data()

# %%
combined.describe()
# Out:
#           thickness         width  ...          week    order_qty
# count  77895.000000  77895.000000  ...  77895.000000  8941.000000
# mean       0.415881   1106.816278  ...      2.237396  1931.882675
# std        0.157734    182.953521  ...      1.551514  1321.492266
# min        0.150000    300.000000  ...      0.000000    14.000000
# 25%        0.300000   1200.000000  ...      1.000000   723.000000
# 50%        0.450000   1200.000000  ...      2.000000  1894.000000
# 75%        0.550000   1200.000000  ...      4.000000  2783.000000
# max        1.200000   1250.000000  ...      6.000000  5550.000000
#
# [8 rows x 11 columns]

# %%
def get_cols_with_no_nans(df,col_type):
    
    '''
    Arguments :
    df : The dataframe to process
    col_type : 
          num : to only get numerical columns with no nans
          no_num : to only get nun-numerical columns with no nans
          all : to get any columns with no nans    
    '''
    if (col_type == 'num'):
        predictors = df.select_dtypes(exclude=['object'])
    elif (col_type == 'no_num'):
        predictors = df.select_dtypes(include=['object'])
    elif (col_type == 'all'):
        predictors = df
    else :
        print('Error : choose a type (num, no_num, all)')
        return 0
    cols_with_no_nans = []
    for col in predictors.columns:
        if not df[col].isnull().any():
            cols_with_no_nans.append(col)
    return cols_with_no_nans

# %%
num_cols = get_cols_with_no_nans(combined , 'num')
cat_cols = get_cols_with_no_nans(combined , 'no_num')

# %%
print ('Number of numerical columns with no nan values :',len(num_cols))
print ('Number of nun-numerical columns with no nan values :',len(cat_cols))
# Out:
# Number of numerical columns with no nan values : 10
# Number of nun-numerical columns with no nan values : 3

# %%
combined = combined[num_cols + cat_cols]
combined.hist(figsize = (12,10))
plt.show()

# %%
train_data = train_data[num_cols + cat_cols]
train_data['Target'] = target

C_mat = train_data.corr()
fig = plt.figure(figsize = (15,15))

sb.heatmap(C_mat, vmax = .8, square = True)
plt.show()

# %%
def oneHotEncode(df,colNames):
    for col in colNames:
        if( df[col].dtype == np.dtype('object')):
            dummies = pd.get_dummies(df[col],prefix=col)
            df = pd.concat([df,dummies],axis=1)

            #drop the encoded column
            df.drop([col],axis = 1 , inplace=True)
    return df
    

print('There were {} columns before encoding categorical features'.format(combined.shape[1]))
combined = oneHotEncode(combined, cat_cols)
print('There are {} columns after encoding categorical features'.format(combined.shape[1]))
# Out:
# There were 13 columns before encoding categorical features
# There are 78 columns after encoding categorical features

# %%
l=len(train_set)
def split_combined():
    global combined
    train = combined[:l]
    test = combined[l:]

    return train , test 
  
train, test = split_combined()

# %%
print(train.shape,test.shape)
# Out:
# (68954, 78) (8941, 78)

# %%
#trying another algorithm
train_X, val_X, train_y, val_y = train_test_split(train, target, test_size = 0.25, random_state = 14)

# %%
NN_model = Sequential()

# The Input Layer :
NN_model.add(Dense(100, kernel_initializer='normal',input_dim = train.shape[1], activation='relu'))

# The Hidden Layers :
NN_model.add(Dense(50, kernel_initializer='normal',activation='relu'))
#NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
#NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))

# The Output Layer :
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))

# Compile the network :
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
NN_model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_10 (Dense)             (None, 100)               7900
# _________________________________________________________________
# dense_11 (Dense)             (None, 50)                5050
# _________________________________________________________________
# dense_12 (Dense)             (None, 1)                 51
# =================================================================
# Total params: 13,001
# Trainable params: 13,001
# Non-trainable params: 0
# _________________________________________________________________

# %%
#checkpoint_name = 'Weights-{epoch:03d}--{val_loss:.5f}.hdf5' 
#checkpoint = ModelCheckpoint(checkpoint_name, monitor='val_loss', verbose = 1, save_best_only = True, mode ='auto')
#callbacks_list = [checkpoint]

# %%
# Load wights file of the best model :
#wights_file = '/content/Weights-183--21.46987.hdf5' # choose the best checkpoint 
#NN_model.load_weights(wights_file) # load it
#NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])

# %%
NN_model.fit(train_X,train_y, epochs=200, batch_size=32, validation_data =(val_X,val_y))
# Out:
# Train on 51715 samples, validate on 17239 samples
# Epoch 1/200
# 51715/51715 [==============================] - 2s 41us/step - loss: 523.5277 - mean_absolute_error: 523.5278 - val_loss: 330.6958 - val_mean_absolute_error: 330.6959
# Epoch 2/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 235.1662 - mean_absolute_error: 235.1660 - val_loss: 189.3039 - val_mean_absolute_error: 189.3040
# Epoch 3/200
# 51715/51715 [==============================] - 2s 41us/step - loss: 170.8502 - mean_absolute_error: 170.8503 - val_loss: 135.4421 - val_mean_absolute_error: 135.4420
# Epoch 4/200
# 51715/51715 [==============================] - 2s 41us/step - loss: 161.7376 - mean_absolute_error: 161.7377 - val_loss: 141.9269 - val_mean_absolute_error: 141.9269
# Epoch 5/200
# 51715/51715 [==============================] - 2s 41us/step - loss: 150.8119 - mean_absolute_error: 150.8118 - val_loss: 144.5485 - val_mean_absolute_error: 144.5485
# Epoch 6/200
# 51715/51715 [==============================] - 2s 41us/step - loss: 141.7761 - mean_absolute_error: 141.7761 - val_loss: 116.1672 - val_mean_absolute_error: 116.1672
# Epoch 7/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 135.3086 - mean_absolute_error: 135.3085 - val_loss: 117.0467 - val_mean_absolute_error: 117.0466
# Epoch 8/200
# 51715/51715 [==============================] - 2s 41us/step - loss: 124.4465 - mean_absolute_error: 124.4464 - val_loss: 96.8889 - val_mean_absolute_error: 96.8889
# Epoch 9/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 119.3027 - mean_absolute_error: 119.3028 - val_loss: 136.8535 - val_mean_absolute_error: 136.8535
# Epoch 10/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 118.1702 - mean_absolute_error: 118.1702 - val_loss: 110.5849 - val_mean_absolute_error: 110.5849
# Epoch 11/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 116.9397 - mean_absolute_error: 116.9397 - val_loss: 135.5351 - val_mean_absolute_error: 135.5351
# Epoch 12/200
# 51715/51715 [==============================] - 2s 39us/step - loss: 127.9907 - mean_absolute_error: 127.9907 - val_loss: 97.2269 - val_mean_absolute_error: 97.2269
# Epoch 13/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 111.8581 - mean_absolute_error: 111.8581 - val_loss: 138.5070 - val_mean_absolute_error: 138.5071
# Epoch 14/200
# 51715/51715 [==============================] - 2s 42us/step - loss: 105.8287 - mean_absolute_error: 105.8286 - val_loss: 129.4279 - val_mean_absolute_error: 129.4279
# Epoch 15/200
# 51715/51715 [==============================] - 2s 42us/step - loss: 107.4192 - mean_absolute_error: 107.4192 - val_loss: 150.0875 - val_mean_absolute_error: 150.0875
# Epoch 16/200
# 51715/51715 [==============================] - 2s 42us/step - loss: 98.9072 - mean_absolute_error: 98.9073 - val_loss: 137.9874 - val_mean_absolute_error: 137.9874
# Epoch 17/200
# 51715/51715 [==============================] - 2s 39us/step - loss: 96.5647 - mean_absolute_error: 96.5647 - val_loss: 122.4595 - val_mean_absolute_error: 122.4595
# Epoch 18/200
# 51715/51715 [==============================] - 2s 39us/step - loss: 107.7250 - mean_absolute_error: 107.7250 - val_loss: 126.3398 - val_mean_absolute_error: 126.3399
# Epoch 19/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 98.3762 - mean_absolute_error: 98.3762 - val_loss: 110.1538 - val_mean_absolute_error: 110.1538
# Epoch 20/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 93.1801 - mean_absolute_error: 93.1801 - val_loss: 76.4065 - val_mean_absolute_error: 76.4065
# Epoch 21/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 89.4819 - mean_absolute_error: 89.4819 - val_loss: 145.5538 - val_mean_absolute_error: 145.5538
# Epoch 22/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 91.1984 - mean_absolute_error: 91.1984 - val_loss: 67.1896 - val_mean_absolute_error: 67.1896
# Epoch 23/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 81.2449 - mean_absolute_error: 81.2449 - val_loss: 85.7314 - val_mean_absolute_error: 85.7314
# Epoch 24/200
# 51715/51715 [==============================] - 2s 41us/step - loss: 82.8623 - mean_absolute_error: 82.8624 - val_loss: 74.9460 - val_mean_absolute_error: 74.9459
# Epoch 25/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 82.8829 - mean_absolute_error: 82.8829 - val_loss: 79.6254 - val_mean_absolute_error: 79.6254
# Epoch 26/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 80.6400 - mean_absolute_error: 80.6400 - val_loss: 137.6289 - val_mean_absolute_error: 137.6289
# Epoch 27/200
# 51715/51715 [==============================] - 2s 41us/step - loss: 77.3569 - mean_absolute_error: 77.3570 - val_loss: 93.6172 - val_mean_absolute_error: 93.6172
# Epoch 28/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 74.1278 - mean_absolute_error: 74.1278 - val_loss: 89.4301 - val_mean_absolute_error: 89.4301
# Epoch 29/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 74.3274 - mean_absolute_error: 74.3274 - val_loss: 70.2860 - val_mean_absolute_error: 70.2860
# Epoch 30/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 73.1682 - mean_absolute_error: 73.1682 - val_loss: 55.6340 - val_mean_absolute_error: 55.6340
# Epoch 31/200
# 51715/51715 [==============================] - 2s 39us/step - loss: 72.4521 - mean_absolute_error: 72.4521 - val_loss: 55.6018 - val_mean_absolute_error: 55.6018
# Epoch 32/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 66.8909 - mean_absolute_error: 66.8909 - val_loss: 58.5514 - val_mean_absolute_error: 58.5514
# Epoch 33/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 67.1719 - mean_absolute_error: 67.1720 - val_loss: 63.3047 - val_mean_absolute_error: 63.3047
# Epoch 34/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 64.8502 - mean_absolute_error: 64.8503 - val_loss: 68.9326 - val_mean_absolute_error: 68.9326
# Epoch 35/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 64.0289 - mean_absolute_error: 64.0289 - val_loss: 68.6867 - val_mean_absolute_error: 68.6867
# Epoch 36/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 64.0632 - mean_absolute_error: 64.0632 - val_loss: 93.3483 - val_mean_absolute_error: 93.3483
# Epoch 37/200
# 51715/51715 [==============================] - 2s 41us/step - loss: 64.6784 - mean_absolute_error: 64.6784 - val_loss: 74.9833 - val_mean_absolute_error: 74.9833
# Epoch 38/200
# 51715/51715 [==============================] - 2s 41us/step - loss: 62.9324 - mean_absolute_error: 62.9324 - val_loss: 92.8137 - val_mean_absolute_error: 92.8137
# Epoch 39/200
# 51715/51715 [==============================] - 2s 42us/step - loss: 65.1029 - mean_absolute_error: 65.1029 - val_loss: 74.5470 - val_mean_absolute_error: 74.5470
# Epoch 40/200
# 51715/51715 [==============================] - 2s 42us/step - loss: 62.3195 - mean_absolute_error: 62.3196 - val_loss: 64.1875 - val_mean_absolute_error: 64.1875
# Epoch 41/200
# 51715/51715 [==============================] - 2s 41us/step - loss: 59.6589 - mean_absolute_error: 59.6589 - val_loss: 65.5456 - val_mean_absolute_error: 65.5456
# Epoch 42/200
# 51715/51715 [==============================] - 2s 41us/step - loss: 63.1427 - mean_absolute_error: 63.1427 - val_loss: 86.1967 - val_mean_absolute_error: 86.1967
# Epoch 43/200
# 51715/51715 [==============================] - 2s 41us/step - loss: 60.3659 - mean_absolute_error: 60.3659 - val_loss: 90.3311 - val_mean_absolute_error: 90.3311
# Epoch 44/200
# 51715/51715 [==============================] - 2s 41us/step - loss: 62.7199 - mean_absolute_error: 62.7199 - val_loss: 45.7056 - val_mean_absolute_error: 45.7055
# Epoch 45/200
# 51715/51715 [==============================] - 2s 42us/step - loss: 60.7342 - mean_absolute_error: 60.7343 - val_loss: 101.0382 - val_mean_absolute_error: 101.0382
# Epoch 46/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 60.6581 - mean_absolute_error: 60.6581 - val_loss: 73.1568 - val_mean_absolute_error: 73.1568
# Epoch 47/200
# 51715/51715 [==============================] - 2s 39us/step - loss: 56.7424 - mean_absolute_error: 56.7424 - val_loss: 40.5881 - val_mean_absolute_error: 40.5881
# Epoch 48/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 56.2307 - mean_absolute_error: 56.2307 - val_loss: 61.9220 - val_mean_absolute_error: 61.9220
# Epoch 49/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 56.6971 - mean_absolute_error: 56.6970 - val_loss: 83.5913 - val_mean_absolute_error: 83.5913
# Epoch 50/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 58.6979 - mean_absolute_error: 58.6978 - val_loss: 54.5510 - val_mean_absolute_error: 54.5510
# Epoch 51/200
# 51715/51715 [==============================] - 2s 39us/step - loss: 56.2786 - mean_absolute_error: 56.2787 - val_loss: 88.8320 - val_mean_absolute_error: 88.8321
# Epoch 52/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 57.2344 - mean_absolute_error: 57.2343 - val_loss: 101.2168 - val_mean_absolute_error: 101.2169
# Epoch 53/200
# 51715/51715 [==============================] - 2s 41us/step - loss: 57.5362 - mean_absolute_error: 57.5362 - val_loss: 70.5680 - val_mean_absolute_error: 70.5680
# Epoch 54/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 55.6813 - mean_absolute_error: 55.6813 - val_loss: 45.2078 - val_mean_absolute_error: 45.2078
# Epoch 55/200
# 51715/51715 [==============================] - 2s 41us/step - loss: 55.5779 - mean_absolute_error: 55.5778 - val_loss: 36.4636 - val_mean_absolute_error: 36.4636
# Epoch 56/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 55.1254 - mean_absolute_error: 55.1254 - val_loss: 47.2534 - val_mean_absolute_error: 47.2534
# Epoch 57/200
# 51715/51715 [==============================] - 2s 41us/step - loss: 54.1062 - mean_absolute_error: 54.1063 - val_loss: 57.8405 - val_mean_absolute_error: 57.8405
# Epoch 58/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 52.7951 - mean_absolute_error: 52.7952 - val_loss: 63.7513 - val_mean_absolute_error: 63.7513
# Epoch 59/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 51.7570 - mean_absolute_error: 51.7569 - val_loss: 40.4010 - val_mean_absolute_error: 40.4010
# Epoch 60/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 51.5312 - mean_absolute_error: 51.5312 - val_loss: 45.3198 - val_mean_absolute_error: 45.3198
# Epoch 61/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 51.3606 - mean_absolute_error: 51.3605 - val_loss: 36.6685 - val_mean_absolute_error: 36.6685
# Epoch 62/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 51.4466 - mean_absolute_error: 51.4466 - val_loss: 103.4956 - val_mean_absolute_error: 103.4956
# Epoch 63/200
# 51715/51715 [==============================] - 2s 41us/step - loss: 51.6782 - mean_absolute_error: 51.6782 - val_loss: 127.5237 - val_mean_absolute_error: 127.5237
# Epoch 64/200
# 51715/51715 [==============================] - 2s 41us/step - loss: 51.1685 - mean_absolute_error: 51.1684 - val_loss: 56.6607 - val_mean_absolute_error: 56.6607
# Epoch 65/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 48.5959 - mean_absolute_error: 48.5958 - val_loss: 58.6053 - val_mean_absolute_error: 58.6053
# Epoch 66/200
# 51715/51715 [==============================] - 2s 41us/step - loss: 50.4121 - mean_absolute_error: 50.4122 - val_loss: 66.1828 - val_mean_absolute_error: 66.1828
# Epoch 67/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 50.9137 - mean_absolute_error: 50.9138 - val_loss: 36.1761 - val_mean_absolute_error: 36.1761
# Epoch 68/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 49.6006 - mean_absolute_error: 49.6007 - val_loss: 121.3114 - val_mean_absolute_error: 121.3114
# Epoch 69/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 48.4762 - mean_absolute_error: 48.4762 - val_loss: 80.1703 - val_mean_absolute_error: 80.1703
# Epoch 70/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 48.2931 - mean_absolute_error: 48.2931 - val_loss: 55.5496 - val_mean_absolute_error: 55.5496
# Epoch 71/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 47.1125 - mean_absolute_error: 47.1125 - val_loss: 46.1460 - val_mean_absolute_error: 46.1460
# Epoch 72/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 49.0974 - mean_absolute_error: 49.0975 - val_loss: 64.9493 - val_mean_absolute_error: 64.9493
# Epoch 73/200
# 51715/51715 [==============================] - 2s 39us/step - loss: 51.3857 - mean_absolute_error: 51.3857 - val_loss: 32.4027 - val_mean_absolute_error: 32.4027
# Epoch 74/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 50.2810 - mean_absolute_error: 50.2811 - val_loss: 76.1313 - val_mean_absolute_error: 76.1313
# Epoch 75/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 47.6292 - mean_absolute_error: 47.6292 - val_loss: 43.9277 - val_mean_absolute_error: 43.9277
# Epoch 76/200
# 51715/51715 [==============================] - 2s 39us/step - loss: 49.6112 - mean_absolute_error: 49.6112 - val_loss: 94.4874 - val_mean_absolute_error: 94.4874
# Epoch 77/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 47.1941 - mean_absolute_error: 47.1942 - val_loss: 45.9469 - val_mean_absolute_error: 45.9469
# Epoch 78/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 45.8733 - mean_absolute_error: 45.8733 - val_loss: 68.5191 - val_mean_absolute_error: 68.5191
# Epoch 79/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 49.5040 - mean_absolute_error: 49.5039 - val_loss: 133.9806 - val_mean_absolute_error: 133.9806
# Epoch 80/200
# 51715/51715 [==============================] - 2s 41us/step - loss: 49.6867 - mean_absolute_error: 49.6867 - val_loss: 35.9223 - val_mean_absolute_error: 35.9223
# Epoch 81/200
# 51715/51715 [==============================] - 2s 41us/step - loss: 46.5673 - mean_absolute_error: 46.5672 - val_loss: 32.5487 - val_mean_absolute_error: 32.5487
# Epoch 82/200
# 51715/51715 [==============================] - 2s 41us/step - loss: 47.6510 - mean_absolute_error: 47.6509 - val_loss: 70.6228 - val_mean_absolute_error: 70.6228
# Epoch 83/200
# 51715/51715 [==============================] - 2s 41us/step - loss: 49.7131 - mean_absolute_error: 49.7132 - val_loss: 33.0528 - val_mean_absolute_error: 33.0528
# Epoch 84/200
# 51715/51715 [==============================] - 2s 41us/step - loss: 46.2128 - mean_absolute_error: 46.2128 - val_loss: 104.5892 - val_mean_absolute_error: 104.5892
# Epoch 85/200
# 51715/51715 [==============================] - 2s 39us/step - loss: 47.4889 - mean_absolute_error: 47.4889 - val_loss: 36.5242 - val_mean_absolute_error: 36.5242
# Epoch 86/200
# 51715/51715 [==============================] - 2s 39us/step - loss: 45.6419 - mean_absolute_error: 45.6419 - val_loss: 72.4241 - val_mean_absolute_error: 72.4241
# Epoch 87/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 46.7792 - mean_absolute_error: 46.7792 - val_loss: 86.5744 - val_mean_absolute_error: 86.5744
# Epoch 88/200
# 51715/51715 [==============================] - 2s 39us/step - loss: 45.3946 - mean_absolute_error: 45.3946 - val_loss: 45.3276 - val_mean_absolute_error: 45.3276
# Epoch 89/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 47.4410 - mean_absolute_error: 47.4410 - val_loss: 88.8078 - val_mean_absolute_error: 88.8078
# Epoch 90/200
# 51715/51715 [==============================] - 2s 45us/step - loss: 45.9278 - mean_absolute_error: 45.9278 - val_loss: 38.1645 - val_mean_absolute_error: 38.1645
# Epoch 91/200
# 51715/51715 [==============================] - 2s 43us/step - loss: 46.0888 - mean_absolute_error: 46.0889 - val_loss: 41.8833 - val_mean_absolute_error: 41.8833
# Epoch 92/200
# 51715/51715 [==============================] - 2s 44us/step - loss: 47.4925 - mean_absolute_error: 47.4925 - val_loss: 57.2738 - val_mean_absolute_error: 57.2738
# Epoch 93/200
# 51715/51715 [==============================] - 2s 43us/step - loss: 44.5584 - mean_absolute_error: 44.5584 - val_loss: 30.1081 - val_mean_absolute_error: 30.1081
# Epoch 94/200
# 51715/51715 [==============================] - 2s 43us/step - loss: 44.2263 - mean_absolute_error: 44.2264 - val_loss: 78.7290 - val_mean_absolute_error: 78.7290
# Epoch 95/200
# 51715/51715 [==============================] - 2s 39us/step - loss: 51.4588 - mean_absolute_error: 51.4588 - val_loss: 50.2732 - val_mean_absolute_error: 50.2732
# Epoch 96/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 46.9944 - mean_absolute_error: 46.9944 - val_loss: 54.1868 - val_mean_absolute_error: 54.1868
# Epoch 97/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 44.1484 - mean_absolute_error: 44.1484 - val_loss: 31.5586 - val_mean_absolute_error: 31.5586
# Epoch 98/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 43.0003 - mean_absolute_error: 43.0003 - val_loss: 66.8596 - val_mean_absolute_error: 66.8597
# Epoch 99/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 44.2004 - mean_absolute_error: 44.2004 - val_loss: 67.9519 - val_mean_absolute_error: 67.9518
# Epoch 100/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 40.1105 - mean_absolute_error: 40.1106 - val_loss: 44.9126 - val_mean_absolute_error: 44.9126
# Epoch 101/200
# 51715/51715 [==============================] - 2s 39us/step - loss: 44.8054 - mean_absolute_error: 44.8054 - val_loss: 59.7885 - val_mean_absolute_error: 59.7884
# Epoch 102/200
# 51715/51715 [==============================] - 2s 39us/step - loss: 43.6209 - mean_absolute_error: 43.6209 - val_loss: 35.6236 - val_mean_absolute_error: 35.6236
# Epoch 103/200
# 51715/51715 [==============================] - 2s 39us/step - loss: 44.5838 - mean_absolute_error: 44.5838 - val_loss: 35.6422 - val_mean_absolute_error: 35.6422
# Epoch 104/200
# 51715/51715 [==============================] - 2s 39us/step - loss: 45.9213 - mean_absolute_error: 45.9212 - val_loss: 34.0296 - val_mean_absolute_error: 34.0296
# Epoch 105/200
# 51715/51715 [==============================] - 2s 39us/step - loss: 44.5789 - mean_absolute_error: 44.5789 - val_loss: 32.5380 - val_mean_absolute_error: 32.5380
# Epoch 106/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 44.1352 - mean_absolute_error: 44.1352 - val_loss: 53.0274 - val_mean_absolute_error: 53.0275
# Epoch 107/200
# 51715/51715 [==============================] - 2s 39us/step - loss: 42.3972 - mean_absolute_error: 42.3972 - val_loss: 68.7696 - val_mean_absolute_error: 68.7697
# Epoch 108/200
# 51715/51715 [==============================] - 2s 38us/step - loss: 42.6401 - mean_absolute_error: 42.6401 - val_loss: 46.3374 - val_mean_absolute_error: 46.3374
# Epoch 109/200
# 51715/51715 [==============================] - 2s 38us/step - loss: 41.3122 - mean_absolute_error: 41.3121 - val_loss: 45.1816 - val_mean_absolute_error: 45.1817
# Epoch 110/200
# 51715/51715 [==============================] - 2s 38us/step - loss: 41.2806 - mean_absolute_error: 41.2806 - val_loss: 50.6092 - val_mean_absolute_error: 50.6091
# Epoch 111/200
# 51715/51715 [==============================] - 2s 38us/step - loss: 42.1831 - mean_absolute_error: 42.1832 - val_loss: 43.8782 - val_mean_absolute_error: 43.8782
# Epoch 112/200
# 51715/51715 [==============================] - 2s 37us/step - loss: 44.3886 - mean_absolute_error: 44.3886 - val_loss: 72.4445 - val_mean_absolute_error: 72.4446
# Epoch 113/200
# 51715/51715 [==============================] - 2s 38us/step - loss: 45.6493 - mean_absolute_error: 45.6493 - val_loss: 171.2577 - val_mean_absolute_error: 171.2578
# Epoch 114/200
# 51715/51715 [==============================] - 2s 39us/step - loss: 43.5049 - mean_absolute_error: 43.5049 - val_loss: 35.2357 - val_mean_absolute_error: 35.2357
# Epoch 115/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 41.4521 - mean_absolute_error: 41.4521 - val_loss: 25.8452 - val_mean_absolute_error: 25.8452
# Epoch 116/200
# 51715/51715 [==============================] - 2s 41us/step - loss: 44.3756 - mean_absolute_error: 44.3756 - val_loss: 58.9297 - val_mean_absolute_error: 58.9297
# Epoch 117/200
# 51715/51715 [==============================] - 2s 41us/step - loss: 41.3526 - mean_absolute_error: 41.3525 - val_loss: 48.6053 - val_mean_absolute_error: 48.6053
# Epoch 118/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 39.0690 - mean_absolute_error: 39.0690 - val_loss: 40.4189 - val_mean_absolute_error: 40.4189
# Epoch 119/200
# 51715/51715 [==============================] - 2s 41us/step - loss: 41.6040 - mean_absolute_error: 41.6040 - val_loss: 35.3270 - val_mean_absolute_error: 35.3270
# Epoch 120/200
# 51715/51715 [==============================] - 2s 42us/step - loss: 38.9783 - mean_absolute_error: 38.9784 - val_loss: 26.1244 - val_mean_absolute_error: 26.1244
# Epoch 121/200
# 51715/51715 [==============================] - 2s 42us/step - loss: 40.9234 - mean_absolute_error: 40.9234 - val_loss: 68.4373 - val_mean_absolute_error: 68.4374
# Epoch 122/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 41.0112 - mean_absolute_error: 41.0112 - val_loss: 41.3165 - val_mean_absolute_error: 41.3165
# Epoch 123/200
# 51715/51715 [==============================] - 2s 39us/step - loss: 39.6515 - mean_absolute_error: 39.6515 - val_loss: 35.8587 - val_mean_absolute_error: 35.8587
# Epoch 124/200
# 51715/51715 [==============================] - 2s 38us/step - loss: 41.7753 - mean_absolute_error: 41.7753 - val_loss: 58.2382 - val_mean_absolute_error: 58.2381
# Epoch 125/200
# 51715/51715 [==============================] - 2s 38us/step - loss: 38.3849 - mean_absolute_error: 38.3849 - val_loss: 55.5495 - val_mean_absolute_error: 55.5495
# Epoch 126/200
# 51715/51715 [==============================] - 2s 38us/step - loss: 40.3139 - mean_absolute_error: 40.3139 - val_loss: 43.7171 - val_mean_absolute_error: 43.7171
# Epoch 127/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 39.7609 - mean_absolute_error: 39.7609 - val_loss: 39.9492 - val_mean_absolute_error: 39.9492
# Epoch 128/200
# 51715/51715 [==============================] - 2s 39us/step - loss: 39.3891 - mean_absolute_error: 39.3891 - val_loss: 29.0739 - val_mean_absolute_error: 29.0739
# Epoch 129/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 39.6223 - mean_absolute_error: 39.6224 - val_loss: 49.0389 - val_mean_absolute_error: 49.0389
# Epoch 130/200
# 51715/51715 [==============================] - 2s 39us/step - loss: 37.6437 - mean_absolute_error: 37.6437 - val_loss: 50.0648 - val_mean_absolute_error: 50.0648
# Epoch 131/200
# 51715/51715 [==============================] - 2s 39us/step - loss: 39.5302 - mean_absolute_error: 39.5302 - val_loss: 66.0875 - val_mean_absolute_error: 66.0875
# Epoch 132/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 40.8151 - mean_absolute_error: 40.8151 - val_loss: 66.8760 - val_mean_absolute_error: 66.8760
# Epoch 133/200
# 51715/51715 [==============================] - 2s 41us/step - loss: 40.3156 - mean_absolute_error: 40.3156 - val_loss: 59.9334 - val_mean_absolute_error: 59.9334
# Epoch 134/200
# 51715/51715 [==============================] - 2s 39us/step - loss: 40.6280 - mean_absolute_error: 40.6280 - val_loss: 41.2250 - val_mean_absolute_error: 41.2250
# Epoch 135/200
# 51715/51715 [==============================] - 2s 39us/step - loss: 40.8079 - mean_absolute_error: 40.8079 - val_loss: 84.9344 - val_mean_absolute_error: 84.9344
# Epoch 136/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 39.4378 - mean_absolute_error: 39.4378 - val_loss: 27.7872 - val_mean_absolute_error: 27.7871
# Epoch 137/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 38.5972 - mean_absolute_error: 38.5972 - val_loss: 41.9144 - val_mean_absolute_error: 41.9144
# Epoch 138/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 38.7413 - mean_absolute_error: 38.7413 - val_loss: 43.0333 - val_mean_absolute_error: 43.0333
# Epoch 139/200
# 51715/51715 [==============================] - 2s 39us/step - loss: 38.9655 - mean_absolute_error: 38.9655 - val_loss: 43.4510 - val_mean_absolute_error: 43.4510
# Epoch 140/200
# 51715/51715 [==============================] - 2s 39us/step - loss: 37.8146 - mean_absolute_error: 37.8146 - val_loss: 64.4561 - val_mean_absolute_error: 64.4561
# Epoch 141/200
# 51715/51715 [==============================] - 2s 39us/step - loss: 39.7238 - mean_absolute_error: 39.7238 - val_loss: 33.5878 - val_mean_absolute_error: 33.5878
# Epoch 142/200
# 51715/51715 [==============================] - 2s 38us/step - loss: 39.7581 - mean_absolute_error: 39.7582 - val_loss: 46.1886 - val_mean_absolute_error: 46.1886
# Epoch 143/200
# 51715/51715 [==============================] - 2s 38us/step - loss: 40.5139 - mean_absolute_error: 40.5139 - val_loss: 25.4821 - val_mean_absolute_error: 25.4821
# Epoch 144/200
# 51715/51715 [==============================] - 2s 38us/step - loss: 41.2811 - mean_absolute_error: 41.2811 - val_loss: 62.1015 - val_mean_absolute_error: 62.1015
# Epoch 145/200
# 51715/51715 [==============================] - 2s 38us/step - loss: 39.7674 - mean_absolute_error: 39.7674 - val_loss: 73.7828 - val_mean_absolute_error: 73.7828
# Epoch 146/200
# 51715/51715 [==============================] - 2s 39us/step - loss: 37.8651 - mean_absolute_error: 37.8651 - val_loss: 23.5728 - val_mean_absolute_error: 23.5728
# Epoch 147/200
# 51715/51715 [==============================] - 2s 39us/step - loss: 37.9627 - mean_absolute_error: 37.9627 - val_loss: 50.1060 - val_mean_absolute_error: 50.1060
# Epoch 148/200
# 51715/51715 [==============================] - 2s 38us/step - loss: 38.4009 - mean_absolute_error: 38.4009 - val_loss: 55.8398 - val_mean_absolute_error: 55.8398
# Epoch 149/200
# 51715/51715 [==============================] - 2s 39us/step - loss: 38.5430 - mean_absolute_error: 38.5430 - val_loss: 33.5817 - val_mean_absolute_error: 33.5817
# Epoch 150/200
# 51715/51715 [==============================] - 2s 39us/step - loss: 37.6273 - mean_absolute_error: 37.6273 - val_loss: 48.1195 - val_mean_absolute_error: 48.1195
# Epoch 151/200
# 51715/51715 [==============================] - 2s 39us/step - loss: 37.5372 - mean_absolute_error: 37.5373 - val_loss: 41.9149 - val_mean_absolute_error: 41.9149
# Epoch 152/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 39.8735 - mean_absolute_error: 39.8735 - val_loss: 38.0692 - val_mean_absolute_error: 38.0692
# Epoch 153/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 36.0833 - mean_absolute_error: 36.0833 - val_loss: 60.3979 - val_mean_absolute_error: 60.3979
# Epoch 154/200
# 51715/51715 [==============================] - 2s 39us/step - loss: 38.2268 - mean_absolute_error: 38.2268 - val_loss: 24.2586 - val_mean_absolute_error: 24.2586
# Epoch 155/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 36.4173 - mean_absolute_error: 36.4173 - val_loss: 43.0008 - val_mean_absolute_error: 43.0008
# Epoch 156/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 37.0980 - mean_absolute_error: 37.0980 - val_loss: 63.7636 - val_mean_absolute_error: 63.7636
# Epoch 157/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 38.6953 - mean_absolute_error: 38.6953 - val_loss: 67.9949 - val_mean_absolute_error: 67.9949
# Epoch 158/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 37.8141 - mean_absolute_error: 37.8141 - val_loss: 61.1189 - val_mean_absolute_error: 61.1189
# Epoch 159/200
# 51715/51715 [==============================] - 2s 41us/step - loss: 38.2046 - mean_absolute_error: 38.2046 - val_loss: 27.0377 - val_mean_absolute_error: 27.0376
# Epoch 160/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 37.6686 - mean_absolute_error: 37.6686 - val_loss: 32.9625 - val_mean_absolute_error: 32.9625
# Epoch 161/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 36.9694 - mean_absolute_error: 36.9695 - val_loss: 35.3946 - val_mean_absolute_error: 35.3946
# Epoch 162/200
# 51715/51715 [==============================] - 2s 42us/step - loss: 36.6926 - mean_absolute_error: 36.6926 - val_loss: 32.3133 - val_mean_absolute_error: 32.3133
# Epoch 163/200
# 51715/51715 [==============================] - 2s 42us/step - loss: 36.2251 - mean_absolute_error: 36.2251 - val_loss: 28.2721 - val_mean_absolute_error: 28.2721
# Epoch 164/200
# 51715/51715 [==============================] - 2s 41us/step - loss: 36.0507 - mean_absolute_error: 36.0507 - val_loss: 32.9702 - val_mean_absolute_error: 32.9702
# Epoch 165/200
# 51715/51715 [==============================] - 2s 38us/step - loss: 39.0728 - mean_absolute_error: 39.0728 - val_loss: 53.4760 - val_mean_absolute_error: 53.4760
# Epoch 166/200
# 51715/51715 [==============================] - 2s 39us/step - loss: 38.1039 - mean_absolute_error: 38.1039 - val_loss: 67.0843 - val_mean_absolute_error: 67.0843
# Epoch 167/200
# 51715/51715 [==============================] - 2s 38us/step - loss: 37.7086 - mean_absolute_error: 37.7086 - val_loss: 52.8148 - val_mean_absolute_error: 52.8148
# Epoch 168/200
# 51715/51715 [==============================] - 2s 38us/step - loss: 37.4189 - mean_absolute_error: 37.4189 - val_loss: 31.6038 - val_mean_absolute_error: 31.6038
# Epoch 169/200
# 51715/51715 [==============================] - 2s 39us/step - loss: 36.2908 - mean_absolute_error: 36.2908 - val_loss: 47.5739 - val_mean_absolute_error: 47.5738
# Epoch 170/200
# 51715/51715 [==============================] - 2s 38us/step - loss: 39.2466 - mean_absolute_error: 39.2466 - val_loss: 23.3504 - val_mean_absolute_error: 23.3504
# Epoch 171/200
# 51715/51715 [==============================] - 2s 39us/step - loss: 36.2426 - mean_absolute_error: 36.2427 - val_loss: 61.6936 - val_mean_absolute_error: 61.6936
# Epoch 172/200
# 51715/51715 [==============================] - 2s 39us/step - loss: 37.9837 - mean_absolute_error: 37.9838 - val_loss: 78.0712 - val_mean_absolute_error: 78.0712
# Epoch 173/200
# 51715/51715 [==============================] - 2s 39us/step - loss: 38.1948 - mean_absolute_error: 38.1948 - val_loss: 26.8196 - val_mean_absolute_error: 26.8196
# Epoch 174/200
# 51715/51715 [==============================] - 2s 39us/step - loss: 38.1782 - mean_absolute_error: 38.1782 - val_loss: 32.5802 - val_mean_absolute_error: 32.5801
# Epoch 175/200
# 51715/51715 [==============================] - 2s 39us/step - loss: 36.5026 - mean_absolute_error: 36.5026 - val_loss: 30.2040 - val_mean_absolute_error: 30.2040
# Epoch 176/200
# 51715/51715 [==============================] - 2s 39us/step - loss: 35.8079 - mean_absolute_error: 35.8079 - val_loss: 38.5938 - val_mean_absolute_error: 38.5938
# Epoch 177/200
# 51715/51715 [==============================] - 2s 39us/step - loss: 36.9331 - mean_absolute_error: 36.9331 - val_loss: 47.6941 - val_mean_absolute_error: 47.6941
# Epoch 178/200
# 51715/51715 [==============================] - 2s 39us/step - loss: 38.0679 - mean_absolute_error: 38.0679 - val_loss: 40.2399 - val_mean_absolute_error: 40.2399
# Epoch 179/200
# 51715/51715 [==============================] - 2s 39us/step - loss: 36.1855 - mean_absolute_error: 36.1855 - val_loss: 28.8033 - val_mean_absolute_error: 28.8033
# Epoch 180/200
# 51715/51715 [==============================] - 2s 39us/step - loss: 36.6028 - mean_absolute_error: 36.6028 - val_loss: 30.2934 - val_mean_absolute_error: 30.2934
# Epoch 181/200
# 51715/51715 [==============================] - 2s 39us/step - loss: 36.2816 - mean_absolute_error: 36.2816 - val_loss: 43.6413 - val_mean_absolute_error: 43.6413
# Epoch 182/200
# 51715/51715 [==============================] - 2s 39us/step - loss: 37.9165 - mean_absolute_error: 37.9165 - val_loss: 39.7056 - val_mean_absolute_error: 39.7056
# Epoch 183/200
# 51715/51715 [==============================] - 2s 39us/step - loss: 35.8262 - mean_absolute_error: 35.8262 - val_loss: 52.2237 - val_mean_absolute_error: 52.2237
# Epoch 184/200
# 51715/51715 [==============================] - 2s 39us/step - loss: 38.0218 - mean_absolute_error: 38.0218 - val_loss: 37.0151 - val_mean_absolute_error: 37.0151
# Epoch 185/200
# 51715/51715 [==============================] - 2s 39us/step - loss: 36.8792 - mean_absolute_error: 36.8791 - val_loss: 31.2983 - val_mean_absolute_error: 31.2983
# Epoch 186/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 36.8628 - mean_absolute_error: 36.8628 - val_loss: 44.2062 - val_mean_absolute_error: 44.2062
# Epoch 187/200
# 51715/51715 [==============================] - 2s 39us/step - loss: 36.3213 - mean_absolute_error: 36.3213 - val_loss: 43.7067 - val_mean_absolute_error: 43.7067
# Epoch 188/200
# 51715/51715 [==============================] - 2s 39us/step - loss: 35.2841 - mean_absolute_error: 35.2841 - val_loss: 43.5141 - val_mean_absolute_error: 43.5141
# Epoch 189/200
# 51715/51715 [==============================] - 2s 39us/step - loss: 36.7336 - mean_absolute_error: 36.7337 - val_loss: 25.4213 - val_mean_absolute_error: 25.4213
# Epoch 190/200
# 51715/51715 [==============================] - 2s 39us/step - loss: 35.3062 - mean_absolute_error: 35.3063 - val_loss: 41.2178 - val_mean_absolute_error: 41.2178
# Epoch 191/200
# 51715/51715 [==============================] - 2s 39us/step - loss: 36.4205 - mean_absolute_error: 36.4204 - val_loss: 47.4112 - val_mean_absolute_error: 47.4112
# Epoch 192/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 35.4194 - mean_absolute_error: 35.4194 - val_loss: 57.7202 - val_mean_absolute_error: 57.7202
# Epoch 193/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 35.9510 - mean_absolute_error: 35.9510 - val_loss: 41.6453 - val_mean_absolute_error: 41.6453
# Epoch 194/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 36.6181 - mean_absolute_error: 36.6180 - val_loss: 25.4927 - val_mean_absolute_error: 25.4927
# Epoch 195/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 35.5081 - mean_absolute_error: 35.5081 - val_loss: 32.2229 - val_mean_absolute_error: 32.2229
# Epoch 196/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 35.6554 - mean_absolute_error: 35.6553 - val_loss: 95.7611 - val_mean_absolute_error: 95.7611
# Epoch 197/200
# 51715/51715 [==============================] - 2s 39us/step - loss: 35.6979 - mean_absolute_error: 35.6979 - val_loss: 40.2832 - val_mean_absolute_error: 40.2832
# Epoch 198/200
# 51715/51715 [==============================] - 2s 40us/step - loss: 34.2762 - mean_absolute_error: 34.2762 - val_loss: 41.1679 - val_mean_absolute_error: 41.1679
# Epoch 199/200
# 51715/51715 [==============================] - 2s 41us/step - loss: 34.9241 - mean_absolute_error: 34.9241 - val_loss: 21.9841 - val_mean_absolute_error: 21.9841
# Epoch 200/200
# 51715/51715 [==============================] - 2s 41us/step - loss: 35.0608 - mean_absolute_error: 35.0608 - val_loss: 23.3748 - val_mean_absolute_error: 23.3748

# %%
from sklearn.metrics import mean_squared_error
pred_nn= NN_model.predict(val_X)
score_nn = np.sqrt(mean_squared_error(val_y,pred_nn))
MAE_nn = mean_absolute_error(val_y , pred_nn)
print (score_nn)
# Out:
# 53.5136762109882

# %%
predictions = NN_model.predict(test)

# %%
print(predictions)
# Out:
# [[1126.1448 ]
#  [1159.5575 ]
#  [1076.4569 ]
#  ...
#  [3163.6013 ]
#  [ 735.94525]
#  [1343.579  ]]

# %%
model = RandomForestRegressor()
model.fit(train_X,train_y)

# Get the mean absolute error on the validation data
pred_rf = model.predict(val_X)
score_rf = np.sqrt(mean_squared_error(val_y,pred_rf))
MAE_rf = mean_absolute_error(val_y , pred_rf)
print(score_rf)
print('Random forest validation MAE = ', MAE_rf)
# Out:
# 46.527261821709125
# Random forest validation MAE =  8.196660850099228

# %%
pred_rf = model.predict(test)

# %%
print(pred_rf)
# Out:
# [1134.19 1163.28 1081.69 ... 2389.02  637.66 1236.36]

# %%
#trying XgRegressor
XGBModel = XGBRegressor()
XGBModel.fit(train_X,train_y , verbose=False)

# Get the mean absolute error on the validation data :
pred_xgb = XGBModel.predict(val_X)
score_xgb = np.sqrt(mean_squared_error(val_y,pred_xgb))
MAE_xgb = mean_absolute_error(val_y , pred_xgb)
print(score_xgb)
print('XGBoost validation MAE = ',MAE_xgb)
# Out:
# [14:53:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 119.92314912425334
# XGBoost validation MAE =  63.35958620475584

# %%
XGBpredictions = XGBModel.predict(test)
